# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

num_puntos = 1000
conjunto_puntos = []
for i in xrange(num_puntos):
    x1= np.random.normal(0.0, 0.55)
    y1= x1*0.1+0.3+np.random.normal(0.0,0.03)
    conjunto_puntos.append([x1, y1])

x_data = [v[0] for v in conjunto_puntos]
y_data = [v[1] for v in conjunto_puntos]

plt.plot(x_data, y_data,'ro',label='Original data')
plt.legend()
plt.show()

# %%
W = tf.Variable(tf.random_uniform([1],-1.0,1.0))
b = tf.Variable(tf.zeros([1]))
y = W * x_data + b

loss = tf.reduce_mean(tf.square(y - y_data))

optimizer = tf.train.GradientDescentOptimizer(0.5)
train = optimizer.minimize(loss)

# %%
init = tf.global_variables_initializer()

sess = tf.Session()
sess.run(init)

for step in xrange(8):
    sess.run(train)
print step, sess.run(W), sess.run(b)
# Out:
# 7 [ 0.1422516] [ 0.30040941]

# %%
plt.plot(x_data, y_data, 'ro')
plt.plot(x_data, sess.run(W) * x_data + sess.run(b))
plt.legend()
plt.show()
# Out:
# /usr/local/lib/python2.7/dist-packages/matplotlib/axes/_axes.py:545: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "

# %%
import numpy as np

num_puntos = 1000
conjunto_puntos = []
for i in xrange(num_puntos):
     x1= np.random.normal(0.0, 0.55)
     y1= x1 * 0.1 + 0.3 + np.random.normal(0.0, 0.03)
     conjunto_puntos.append([x1, y1])

x_data = [v[0] for v in conjunto_puntos]
y_data = [v[1] for v in conjunto_puntos]

import matplotlib.pyplot as plt

#Graphic display
plt.plot(x_data, y_data, 'ro')
plt.legend()
plt.show()

import tensorflow as tf

W = tf.Variable(tf.random_uniform([1], -1.0, 1.0))
b = tf.Variable(tf.zeros([1]))
y = W * x_data + b

loss = tf.reduce_mean(tf.square(y - y_data))
optimizer = tf.train.GradientDescentOptimizer(0.5)
train = optimizer.minimize(loss)

init = tf.initialize_all_variables()

sess = tf.Session()
sess.run(init)

for step in xrange(20):
        sess.run(train)
        print(step, sess.run(W), sess.run(b))
        #Graphic display
        plt.plot(x_data, y_data, 'ro')
        plt.plot(x_data, sess.run(W) * x_data + sess.run(b))
        plt.xlabel('x')
        plt.xlim(-2,2)
        plt.ylim(0.1,0.6)
        plt.ylabel('y')
        plt.legend()
        plt.show()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/tensorflow/python/util/tf_should_use.py:170: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# (0, array([-0.12271588], dtype=float32), array([ 0.30133244], dtype=float32))
# (1, array([-0.05386829], dtype=float32), array([ 0.3008143], dtype=float32))
# (2, array([-0.00616077], dtype=float32), array([ 0.30046314], dtype=float32))
# (3, array([ 0.02689781], dtype=float32), array([ 0.3002198], dtype=float32))
# (4, array([ 0.04980554], dtype=float32), array([ 0.30005121], dtype=float32))
# (5, array([ 0.06567928], dtype=float32), array([ 0.29993436], dtype=float32))
# (6, array([ 0.07667889], dtype=float32), array([ 0.29985341], dtype=float32))
# (7, array([ 0.08430098], dtype=float32), array([ 0.2997973], dtype=float32))
# (8, array([ 0.08958266], dtype=float32), array([ 0.29975843], dtype=float32))
# (9, array([ 0.09324256], dtype=float32), array([ 0.29973149], dtype=float32))
# (10, array([ 0.09577867], dtype=float32), array([ 0.29971281], dtype=float32))
# (11, array([ 0.09753604], dtype=float32), array([ 0.29969987], dtype=float32))
# (12, array([ 0.0987538], dtype=float32), array([ 0.29969093], dtype=float32))
# (13, array([ 0.09959764], dtype=float32), array([ 0.2996847], dtype=float32))
# (14, array([ 0.10018237], dtype=float32), array([ 0.29968041], dtype=float32))
# (15, array([ 0.10058755], dtype=float32), array([ 0.29967743], dtype=float32))
# (16, array([ 0.10086833], dtype=float32), array([ 0.29967535], dtype=float32))
# (17, array([ 0.10106289], dtype=float32), array([ 0.29967391], dtype=float32))
# (18, array([ 0.1011977], dtype=float32), array([ 0.29967293], dtype=float32))
# (19, array([ 0.10129113], dtype=float32), array([ 0.29967225], dtype=float32))
