# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

num_puntos = 1000
conjunto_puntos = []
for i in xrange(num_puntos):
    x1= np.random.normal(0.0, 0.55)
    y1= x1*0.1+0.3+np.random.normal(0.0,0.03)
    conjunto_puntos.append([x1, y1])

x_data = [v[0] for v in conjunto_puntos]
y_data = [v[1] for v in conjunto_puntos]

plt.plot(x_data, y_data,'ro',label='Original data')
plt.legend()
plt.show()

# %%
W = tf.Variable(tf.random_uniform([1],-1.0,1.0))
b = tf.Variable(tf.zeros([1]))
y = W * x_data + b

loss = tf.reduce_mean(tf.square(y - y_data))

optimizer = tf.train.GradientDescentOptimizer(0.5)
train = optimizer.minimize(loss)

# %%
init = tf.global_variables_initializer()

sess = tf.Session()
sess.run(init)

for step in xrange(8):
    sess.run(train)
print step, sess.run(W), sess.run(b)
# Out:
# 7 [0.07023253] [0.299723]

# %%
plt.plot(x_data, y_data, 'ro')
plt.plot(x_data, sess.run(W) * x_data + sess.run(b))
plt.legend()
plt.show()

# %%
import numpy as np

num_puntos = 1000
conjunto_puntos = []
for i in xrange(num_puntos):
     x1= np.random.normal(0.0, 0.55)
     y1= x1 * 0.1 + 0.3 + np.random.normal(0.0, 0.03)
     conjunto_puntos.append([x1, y1])

x_data = [v[0] for v in conjunto_puntos]
y_data = [v[1] for v in conjunto_puntos]

import matplotlib.pyplot as plt

#Graphic display
plt.plot(x_data, y_data, 'ro')
plt.legend()
plt.show()

import tensorflow as tf

W = tf.Variable(tf.random_uniform([1], -1.0, 1.0))
b = tf.Variable(tf.zeros([1]))
y = W * x_data + b

loss = tf.reduce_mean(tf.square(y - y_data))
optimizer = tf.train.GradientDescentOptimizer(0.5)
train = optimizer.minimize(loss)

init = tf.initialize_all_variables()

sess = tf.Session()
sess.run(init)

for step in xrange(20):
        sess.run(train)
        print(step, sess.run(W), sess.run(b))
        #Graphic display
        plt.plot(x_data, y_data, 'ro')
        plt.plot(x_data, sess.run(W) * x_data + sess.run(b))
        plt.xlabel('x')
        plt.xlim(-2,2)
        plt.ylim(0.1,0.6)
        plt.ylabel('y')
        plt.legend()
        plt.show()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/tensorflow/python/util/tf_should_use.py:189: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# (0, array([0.30152673], dtype=float32), array([0.29836255], dtype=float32))
# (1, array([0.23842432], dtype=float32), array([0.2991066], dtype=float32))
# (2, array([0.19517578], dtype=float32), array([0.29963762], dtype=float32))
# (3, array([0.16553432], dtype=float32), array([0.30000156], dtype=float32))
# (4, array([0.14521882], dtype=float32), array([0.30025098], dtype=float32))
# (5, array([0.13129508], dtype=float32), array([0.30042195], dtype=float32))
# (6, array([0.12175211], dtype=float32), array([0.3005391], dtype=float32))
# (7, array([0.1152116], dtype=float32), array([0.30061942], dtype=float32))
# (8, array([0.1107289], dtype=float32), array([0.30067444], dtype=float32))
# (9, array([0.10765657], dtype=float32), array([0.30071217], dtype=float32))
# (10, array([0.10555087], dtype=float32), array([0.30073804], dtype=float32))
# (11, array([0.10410768], dtype=float32), array([0.30075574], dtype=float32))
# (12, array([0.10311855], dtype=float32), array([0.3007679], dtype=float32))
# (13, array([0.10244063], dtype=float32), array([0.3007762], dtype=float32))
# (14, array([0.101976], dtype=float32), array([0.30078194], dtype=float32))
# (15, array([0.10165755], dtype=float32), array([0.30078584], dtype=float32))
# (16, array([0.1014393], dtype=float32), array([0.30078852], dtype=float32))
# (17, array([0.10128971], dtype=float32), array([0.30079034], dtype=float32))
# (18, array([0.10118719], dtype=float32), array([0.3007916], dtype=float32))
# (19, array([0.10111693], dtype=float32), array([0.30079246], dtype=float32))
